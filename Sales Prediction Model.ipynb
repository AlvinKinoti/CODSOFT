# %% [markdown]
# ### Loading the libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# %matplotlib inline

# %% [markdown]
# ### Loading and exploring the dataset

# %%
df = pd.read_csv("advertising.csv")
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.shape
# Out:
# (200, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Visualizing the dataset

# %% [markdown]
# ##### Finding the highest sales volume recorded

# %%
plt.figure(figsize = (5,5))
plt.hist(df["Sales"], bins = 25)
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.grid(True)
plt.title("Frequency of Sales Revenue")
# Out:
# Text(0.5, 1.0, 'Frequency of Sales Revenue')

# %% [markdown]
# ##### Comparision between TV and Radio input and Sales

# %%
Sales = df["Sales"]
TV = df["TV"]
Radio = df["Radio"]

plt.figure(figsize = (10,10))
plt.scatter(Sales, TV, s = 200)
plt.scatter(Sales, Radio, s = 500, marker = "3")
plt.grid(True)
plt.legend(["TV", "Radio"])
plt.title("Sales vs TV and Radio")
plt.xlabel("Sales")
plt.ylabel("TV and Radio")
# Out:
# Text(0, 0.5, 'TV and Radio')

# %% [markdown]
# ### Developing the prediction model

# %%
X = df.drop(columns = ["Sales"])
y = df["Sales"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, y_train, X_test, y_test = train_test_split(X,y, test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score

# %%
lr = LinearRegression()

# %%
lr.fit(X,y)

# %%
pred = lr.predict(X)
pred
# Out:
# array([21.22097209, 11.26824775, 10.49620897, 17.31244651, 15.64413685,
#        10.35633677, 11.2732847 , 13.27062458,  5.31839603, 15.78871013,
#         8.8527202 , 18.88400523,  9.69879662, 10.74921373, 19.27328852,
#        20.38554445, 12.27105794, 24.20214502, 10.5924398 , 15.20872794,
#        19.49794066, 18.10414656,  7.06177654, 18.87221072,  9.37145421,
#        19.31996936, 15.54479137, 19.49216302, 21.07865408, 10.19471067,
#        23.61492832, 12.64683045, 10.08782551, 21.2260486 ,  9.98787085,
#        20.89407055, 23.84503494, 13.99342411,  9.8404516 , 21.08344935,
#        18.04712878, 17.84885818, 23.57494339, 16.79762772,  8.75617872,
#        16.57668108, 10.58020572, 22.13342743, 18.70257411,  9.53181337,
#        15.84670856, 11.11990058, 20.88243422, 19.53008343, 22.01500291,
#        20.76038994,  8.04320903, 14.10063486, 21.4222098 , 19.25650785,
#         7.75915886, 23.43911942, 19.32168181, 13.3867616 , 16.35231896,
# ...

# %%
r2_score(pred, y)
# Out:
# 0.892078827799293

# %% [markdown]
# ##### Conclusion : Sales is highly dependent on the input of TV, Radio and Newspaper outlet inputs

# %% [markdown]
# ### Plotting the results

# %%
plt.figure(figsize=(5,5))
plt.scatter(pred, y, s= 250, color = "green", marker = "4")
plt.xlabel("Predicted Values")
plt.ylabel("Sales")
plt.grid(True)
plt.title(" Estimated Values vs Sales")
# Out:
# Text(0.5, 1.0, ' Estimated Values vs Sales')

# %%
General Conclusion: The model is a good predictor
